# %% [markdown]
# # 1번

# %% [markdown]
# - 사각형 넓이 구하는 문제.

# %%
# import sys


# def getArea(width, height) -> int:
#     '''
#     루프가 없기 때문에 복잡도는 O(1)이다.
#     '''
#     return width*height

# def main():
#     width, height = map(int, sys.stdin.readline().strip().split(' '))

#     if 0<=width<=1024 or 0<=width<=1024:
#         pass
#     else:
#         raise ValueError 
    
#     print(getArea(width, height))
    
    
# main()

# %% [markdown]
# # 2번

# %% [markdown]
# ![2-1.png](attachment:2-1.png)
# ![2-2.png](attachment:2-2.png)
# ![2-3.png](attachment:2-3.png)

# %% [markdown]
# (예제 설명)
# - 5 2 : 명령어 5개 입력할 것임, queue size = 2
# - OFFER A : queue 안에 A를 넣는다.
#     - queue size가 2가 되면 그 다음부턴 OFFER을 해도 넣지 않는다.
# - TAKE : queue 안에 있는 것을 pop(0)로 꺼내서 출력한다.
# - SIZE : queue의 size를 출력해준다.

# %%
# 제출본
import sys

#input 
line = sys.stdin.readline()
firstline = line.split()
comsize = int(firstline[0])
qsize = int(firstline[1])
if 1<= comsize <= 10000 or 1 <= qsize <= 10000:
    pass
else:
    raise ValueError
ls = []


# main
'''
comsize 만큼 선형 입력 받으므로 복잡도는 O(comsize)이다.
'''
for i in range(comsize):
    comline = sys.stdin.readline().rstrip().split()
    com = comline[0]
    if com == 'OFFER':
        param = comline[1]
        if len(ls) >= qsize:
            print('false')
            continue
        else:
            print('true')
        ls.append(param)
    elif com == 'TAKE':
        if len(ls) > 0:
            print(ls.pop(0))
    elif com == 'SIZE':
        print(len(ls))
    else:
        raise ValueError

# %% [markdown]
# # 3번

# %% [markdown]
# - line1에서 두 숫자의 합이 target과 같은 조합이 있으면 그걸 출력. 없으면 -1 출력
# - 만약 여러개가 있다면 가장 작은 숫자를 가지고 있는 조합을 출력.

# %%
line1 = 1, 2, 3, 4, 5
target = 6
#1 5

# %%
#최종본

import sys

#input
line1 = sys.stdin.readline()
target = sys.stdin.readline()
line_ls = list(map(int,line1.split(' ')))

#main
def main(line1, target):
    '''
    line1의 길이 오더로 두 번 for 문이 있기 때문에 복잡도는 O(line1)이다.
    '''
    for i in range(len(line1)):
        for j in range(i+1,len(line1)):
            if line1[i]+line1[j] == target:
                return print(line1[i],line1[j])
    return print(-1)

main(line_ls, int(target))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-5d7dc2e2816e> in <module>
#       6 line1 = sys.stdin.readline()
#       7 target = sys.stdin.readline()
# ----> 8 line_ls = list(map(int,line1.split(' ')))
#       9
#      10 #main
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # 4번

# %% [markdown]
# - 기본 깊이 우선 탐색 알고리즘에서.
# - node에 맞춰서 False list 생성.
# - 이미 지나간 노드는 True로 바꾸기.
# - 노드를 마주쳤는데 그게 True면 cycle이 있다고 판단 후 알고리즘 스탑.

# %%
#ls = [[3], [1,2], [2,3], [3,1]]   # True
ls = [[4], [1,2], [2,3], [3,4]]   # False
#ls = [[3], [0, 1], [1, 2], [2, 0]] #True

# %%
def do_dfs(start, visited, adjlist):
    for w in adjlist[start]:
        if visited[w] == True:
            return True
        visited[w] = True
        return do_dfs(w, visited, adjlist)

'''
인접 리스트를 그래프 표현 구조로 선택했고
적어도 한번은 노드를 지나갔는지 확인해야 하므로
O(vertex 갯수) + O(edge 갯수) 
=> 복잡도는 O(vertex+edge 갯수)이다.
'''    
    
def detect_cycle(adjlist, visited):
    for k in visited.keys():
        if visited[k] == True:
            continue
        else:
            visited[k] = True
            has_cycle = do_dfs(k, visited, adjlist)
            if has_cycle == True:
                return 'true'
    return 'false'

def add_edge_to_adjlist(edge, adjlist):
    v = edge[0]
    w = edge[1]
    adjlist[v].append(w)

def main():
    n = int(input())
    adjlist = {key: [] for key in range(n)}
    visited = dict.fromkeys(range(n), False)
    
    '''
    edge 개수만큼 dict에 넣으므로 복잡도는 O(edge 개수)이다.
    '''
    
    while True:
        try:
            a, b = map(int, input().strip().split(' '))
            edge = (a,b)
            add_edge_to_adjlist(edge, adjlist)
        except EOFError:
            break

    print(detect_cycle(adjlist, visited))
main()

# %%
# 또 다른 답.
def cyclic(g):
    path = set()

    def visit(vertex):
        path.add(vertex)
        for neighbour in g.get(vertex, ()):
            if neighbour in path or visit(neighbour):
                return True
        path.remove(vertex)
        return False

    return any(visit(v) for v in g)

adjlist = {}
for i in edge1:
    edge = (i[0],i[1])
    add_edge_to_adjlist(edge, adjlist)
print(adjlist)

# %% [markdown]
# # 5번

# %%
# a = "2 1 2 -1 3"
#a = "1 1 2 -1 3"
a = "3 1 2 -1 3"
ls = list(map(int, a.strip().split(' ')))
ls
# Out:
# [3, 1, 2, -1, 3]

# %%
# 제출본

#input
ls = []
while True:
    try:
        s=int(input())
        #valueError
        if len(ls) == 0:
            if s < 0  or 3000000000 < s:
                raise ValueError    
        else:
            if s < -3000000000  or 3000000000 < s:
                raise ValueError
        # add s in ls
        ls.append(s)
    except EOFError:
        break

# main  
'''
S_ls 길이만큼 선형 입력 받으므로 복잡도는 O(len(S_ls))이다.
'''
W = ls[0]
S_ls = ls[1:]        
ls0 = []
for i in range(len(S_ls)):
    if i+W > len(S_ls):
        break
    ls0.append(max(S_ls[i:i+W])) 

#output    
while len(ls0) != 0:
    print(ls0.pop(0))
